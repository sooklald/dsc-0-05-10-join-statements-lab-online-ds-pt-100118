# %% [markdown]
# # Join Statements

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on Join statements.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table we will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, we'll use the same Customer Relationship Management (CRM) database we used in our lecture before!
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
#Your code here
import sqlite3
connection = sqlite3.connect('data.sqlite')
cursor = connection.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.

# %%
#Your code here
cursor.execute('''SELECT e.firstname, e.lastname, o.city  FROM employees e
                JOIN offices o ON o.officecode = e.officecode
                 WHERE o.city = 'Boston' ''').fetchall()
# Out:
# [('Julie', 'Firrelli', 'Boston'), ('Steve', 'Patterson', 'Boston')]

# %% [markdown]
# ## Do any offices have no employees?

# %%
#Your code here
cursor.execute('''SELECT o.city, COUNT(e.firstname)  FROM employees e
                JOIN offices o ON o.officecode = e.officecode
                GROUP BY o.city
                HAVING COUNT(e.firstname) = 0
                  ''').fetchall()
# Out:
# []

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold.

# %%
#Your code here
cursor.execute('''SELECT distinct e.firstname, e.lastname, p.productname FROM employees e
                JOIN offices o ON o.officecode = e.officecode
                JOIN customers c ON e.employeenumber = c.salesrepemployeenumber
                JOIN orders ord ON ord.customernumber = c.customernumber
                JOIN orderdetails od ON od.ordernumber = ord.ordernumber
                JOIN products p ON p.productcode = od.productcode
                ORDER BY e.firstname
                  ''').fetchall()
# Out:
# [('Andy', 'Fixter', '1996 Moto Guzzi 1100i'),
#  ('Andy', 'Fixter', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Andy', 'Fixter', 'P-51-D Mustang'),
#  ('Andy', 'Fixter', '1936 Harley Davidson El Knucklehead'),
#  ('Andy', 'Fixter', '1997 BMW R 1100 S'),
#  ('Andy', 'Fixter', '1928 British Royal Navy Airplane'),
#  ('Andy', 'Fixter', '1960 BSA Gold Star DBD34'),
#  ('Andy', 'Fixter', '1900s Vintage Tri-Plane'),
#  ('Andy', 'Fixter', '1997 BMW F650 ST'),
#  ('Andy', 'Fixter', '1928 Ford Phaeton Deluxe'),
#  ('Andy', 'Fixter', '1930 Buick Marquette Phaeton'),
#  ('Andy', 'Fixter', 'American Airlines: B767-300'),
#  ('Andy', 'Fixter', 'America West Airlines B757-200'),
#  ('Andy', 'Fixter', 'ATA: B757-300'),
#  ('Andy', 'Fixter', 'F/A 18 Hornet 1/72'),
#  ('Andy', 'Fixter', '1937 Lincoln Berline'),
#  ('Andy', 'Fixter', '1928 Mercedes-Benz SSK'),
#  ('Andy', 'Fixter', '1969 Harley Davidson Ultimate Chopper'),
#  ('Andy', 'Fixter', '1993 Mazda RX-7'),
# ...

# %% [markdown]
# ## Level Up: Display the Number of Products each Employee Has sold

# %%
#Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use Join statements, along with leveraging your foreign keys knowledge!
